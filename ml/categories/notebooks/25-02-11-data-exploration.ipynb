# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -------------------------------------- - 12.3/12.9 MB 64.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 53.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-calamine
# Out:
# ...
#    ---------------------------------------- 0.0/671.7 kB ? eta -:--:--
#    --------------------------------------- 671.7/671.7 kB 25.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install requests
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import json
import os
import pandas as pd

# %%
# Download from https://open.toronto.ca/dataset/city-subject-thesaurus/
folder = "../data"
filenames = [f"{folder}/{filename}" for filename in os.listdir(folder)]
files = {}
filenames
# Out:
# ['../data/a-bunch-of-agenda-items.csv',
#  '../data/City Subject Thesaurus (CSV).csv',
#  '../data/City Subject Thesaurus (xls).csv',
#  '../data/City Subject Thesaurus (xls).xls',
#  '../data/City Subject Thesaurus Readme.xls',
#  '../data/City Subject Thesaurus.xml']

# %%
# LibreOffice can open it in UTF-8 but not this for some reason
files[filenames[1]] = pd.read_csv((filenames[1]), encoding='cp437')
print(filenames[1])
files[filenames[1]].sample()
# Out:
# ../data/City Subject Thesaurus (CSV).csv
#          Name                                URI  Identifier  \
# 445  builders  http://vocab.toronto.ca/id/101949      101949
#
#                                          Definition(s)  \
# 445  Builder is a person who constructs or renovate...
#
#                                                 Source  \
# 445  From 'Good Neighbour Guide for Residential Inf...
#
#                   Synonym(s)    Status       Broader concept Narrower concept  \
# 445  contractors, renovators  approved  [people in property]              NaN
#
#           Related concept  Legacy ID
# 445  builders, developers        338

# %%
# https://stackoverflow.com/a/66062975
encoding_list = ['ascii', 'big5', 'big5hkscs', 'cp037', 'cp273', 'cp424', 'cp437', 'cp500', 'cp720', 'cp737'
                 , 'cp775', 'cp850', 'cp852', 'cp855', 'cp856', 'cp857', 'cp858', 'cp860', 'cp861', 'cp862'
                 , 'cp863', 'cp864', 'cp865', 'cp866', 'cp869', 'cp874', 'cp875', 'cp932', 'cp949', 'cp950'
                 , 'cp1006', 'cp1026', 'cp1125', 'cp1140', 'cp1250', 'cp1251', 'cp1252', 'cp1253', 'cp1254'
                 , 'cp1255', 'cp1256', 'cp1257', 'cp1258', 'euc_jp', 'euc_jis_2004', 'euc_jisx0213', 'euc_kr'
                 , 'gb2312', 'gbk', 'gb18030', 'hz', 'iso2022_jp', 'iso2022_jp_1', 'iso2022_jp_2'
                 , 'iso2022_jp_2004', 'iso2022_jp_3', 'iso2022_jp_ext', 'iso2022_kr', 'latin_1', 'iso8859_2'
                 , 'iso8859_3', 'iso8859_4', 'iso8859_5', 'iso8859_6', 'iso8859_7', 'iso8859_8', 'iso8859_9'
                 , 'iso8859_10', 'iso8859_11', 'iso8859_13', 'iso8859_14', 'iso8859_15', 'iso8859_16', 'johab'
                 , 'koi8_r', 'koi8_t', 'koi8_u', 'kz1048', 'mac_cyrillic', 'mac_greek', 'mac_iceland', 'mac_latin2'
                 , 'mac_roman', 'mac_turkish', 'ptcp154', 'shift_jis', 'shift_jis_2004', 'shift_jisx0213', 'utf_32'
                 , 'utf_32_be', 'utf_32_le', 'utf_16', 'utf_16_be', 'utf_16_le', 'utf_7', 'utf_8', 'utf_8_sig']

for encoding in encoding_list:
    worked = True
    try:
        df = pd.read_csv(filenames[0], encoding=encoding, nrows=5)
    except:
        worked = False
    if worked:
        print(encoding, ':\n', df.head())
# Out:
# ascii :
#                                                  data
# 0  {"id": "ID_126322", "termId": 8, "wardId": [65...
# 1  {"id": "ID_126326", "termId": 8, "wardId": [68...
# 2  {"id": "ID_126303", "termId": 8, "wardId": [68...
# 3  {"id": "ID_126314", "termId": 8, "wardId": [64...
# 4  {"id": "ID_126323", "termId": 8, "wardId": [65...
# big5 :
#                                                  data
# 0  {"id": "ID_126322", "termId": 8, "wardId": [65...
# 1  {"id": "ID_126326", "termId": 8, "wardId": [68...
# 2  {"id": "ID_126303", "termId": 8, "wardId": [68...
# 3  {"id": "ID_126314", "termId": 8, "wardId": [64...
# 4  {"id": "ID_126323", "termId": 8, "wardId": [65...
# big5hkscs :
#                                                  data
# 0  {"id": "ID_126322", "termId": 8, "wardId": [65...
# 1  {"id": "ID_126326", "termId": 8, "wardId": [68...
# 2  {"id": "ID_126303", "termId": 8, "wardId": [68...
# 3  {"id": "ID_126314", "termId": 8, "wardId": [64...
# ...

# %%
files[filenames[1]].iloc[0]
# Out:
# Name                                          [actions of government]
# URI                                 http://vocab.toronto.ca/id/100783
# Identifier                                                     100783
# Definition(s)                                             placeholder
# Source                                            developed by editor
# Synonym(s)                                                        NaN
# Status                                                       approved
# Broader concept                            [activities in government]
# Narrower concept    business travel (municipal), city initiatives,...
# Related concept                                                   NaN
# Legacy ID                                                        3926
# Name: 0, dtype: object

# %%
# files[filenames[2]] = pd.read_excel((filenames[2]), sheet_name='Subject Thesaurus Data', engine='calamine')
# files[filenames[2]] = pd.read_excel((filenames[2]), sheet_name='Subject Thesaurus Data', engine='xlrd')
# files[filenames[2]] = pd.read_excel((filenames[2]), sheet_name='Subject Thesaurus Data', engine='openpyxl')
files[filenames[2]] = pd.read_csv(filenames[2], encoding='utf-8')
print(filenames[2])
files[filenames[2]].sample()
# Out:
# ../data/City Subject Thesaurus (xls).csv
#               Name                                URI  Identifier  \
# 1571  park benches  http://vocab.toronto.ca/id/101986      101986
#
#      Definition(s)       Source Synonym(s)    Status   Broader concept  \
# 1571   placeholder  placeholder        NaN  approved  park furnishings
#
#            Narrower concept Related concept  Legacy ID
# 1571  commemorative benches             NaN       3245

# %%
# From services\data-fetcher\app\data_fetcher.py
import requests
from datetime import datetime

PAGE_SIZE = 10000

def fetch_data(from_date: str, to_date: str):
    # Validate input dates
    if not validate_datetime(from_date) or not validate_datetime(to_date):
        raise ValueError("Invalid date format. Expected format: YYYY-MM-DDTHH:MM:SS.sssZ")
    
    csrf_url = 'https://secure.toronto.ca/council/api/csrf.json'
    url = "https://secure.toronto.ca/council/api/multiple/agenda-items.json"
    session = requests.Session()

    # GET request to obtain CSRF token
    response = session.get(csrf_url)
    response.raise_for_status()

    # Extract CSRF token from cookies
    cookies = session.cookies.get_dict()
    xsrf_token = cookies.get('XSRF-TOKEN')
    if not xsrf_token:
        raise Exception('XSRF token is missing')

    querystring = {"pageNumber": 0, "pageSize": PAGE_SIZE, "sortOrder": "meetingDate"}

    # Adjust payload as needed or accept parameters from the API endpoint
    payload = {
        "includeTitle": True,
        "includeSummary": True,
        "includeRecommendations": True,
        "includeDecisions": True,
        "meetingFromDate": from_date,
        "meetingToDate": to_date
    }
    headers = {
        "Content-Type": "application/json",
        "X-XSRF-TOKEN": xsrf_token
    }

    response = session.post(url, json=payload, headers=headers, params=querystring, cookies=cookies)
    response.raise_for_status()
    data = response.json()
    return data

def validate_datetime(datetime_string: str):
    try:
        datetime.strptime(datetime_string, "%Y-%m-%dT%H:%M:%S.%fZ")
        return True
    except ValueError:
        return False

# %%
response = fetch_data("2024-02-01T00:00:00.000Z", "2024-02-07T00:00:00.000Z")

# %%
response
# Out:
# {'TotalRecordCount': 158,
#  'PageSize': 10000,
#  'PageNumber': 0,
#  'TotalPages': 1,
#  'Records': [{'id': 'ID_132740',
#    'termId': 8,
#    'agendaItemId': 132740,
#    'councilAgendaItemId': 132740,
#    'decisionBodyId': 2583,
#    'meetingId': 24787,
#    'itemProcessId': 6,
#    'decisionBodyName': 'Civic Appointments Committee',
#    'meetingDate': 1706850000000,
#    'reference': '2024.CA13.3',
#    'termYear': '2024',
#    'agendaCd': 'CA',
#    'meetingNumber': '13',
#    'itemStatus': 'RECEIVED',
#    'agendaItemTitle': 'Overview of 2024 Work Plan for the Civic Appointments Committee',
#    'agendaItemSummary': "<p>The Manager, Public Appointments Secretariat will deliver a presentation to the Civic Appointments Committee on the Committee's 2024 work plan.</p>",
#    'agendaItemRecommendation': '<p>The City Clerk recommends that:</p>\r\n<p>&nbsp;</p>\r\n<p>1. The Civic Appointments Committee receive this report and presentation for information.</p>',
# ...
